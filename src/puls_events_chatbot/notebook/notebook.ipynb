# %%
import pandas as pd

# %%
df = pd.read_csv('../data/evenements.csv',sep=';')

# %%
df
# Out:
#               ID                                               Slug  \
# 0       15268997               atelier-creation-dentreprise-3243132
# 1       50737223                         la-classe-loeuvre--6944943
# 2       92831157                      visite-atelier-adultesenfants
# 3       53456762                   les-jeudis-de-linsertion-4071122
# 4       67676934  formation-cap-metiers-de-bouche-boucherboulang...
# ...          ...                                                ...
# 909885  77335011                                    jenifer-2381838
# 909886  33054961       rencontre-inter-degre-srav-usep-unss-4669373
# 909887   3102394          fete-du-velo-au-centre-juno-beach-1090822
# 909888  76863502  mobilite-active-a-velobus-et-velocoque-esat-pa...
# 909889  14608802   nuit-de-la-chauve-souris-au-grand-voyeux-3859697
#
#                                                       URL  \
# 0       https://openagenda.com/pole-emploi/events/atel...
# ...

# %%
df = df.loc[df['Region'] == 'Île-de-France']
df['Region'].value_counts()
# Out:
# Region
# Île-de-France    171601
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'Slug', 'URL', 'Title', 'Description', 'Long description',
#        'Details', 'Keywords', 'Image', 'Credits for the image', 'Preview',
#        'Source image', 'Last update', 'Times', 'First date - Beginning',
#        'First date - End', 'Last date - Beginning', 'Last date - End',
#        'Detailed times', 'Accessibility code', 'Accessibility', 'Place ID',
#        'Coordinates', 'Place name', 'Address', 'Arrondissement', 'INSEE code',
#        'Postal code', 'City', 'Department', 'Region', 'Country', 'Place image',
#        'Credits for the place image', 'Phone number', 'Place website',
#        'Place links', 'Place tags', 'Place description', 'Access',
#        'Physical or online event', 'Online access link', 'Status',
#        'Minimum age', 'Maximum age', 'Source agenda (title)',
#        'Source agenda (uid)', 'Contributor email', 'Contributor phone number',
#        'Contributor name', 'Contributor function', 'Contributor organisation',
# ...

# %%
df = df.drop(columns=[
    'ID',
    'Slug',
    'Keywords', 
    'Credits for the image',
    'Source image',
    'Last update',
    'Detailed times',
    'Accessibility code',
    'Place ID',
    'Coordinates',
    'INSEE code',
    'Country',
    'Credits for the place image',
    'Place links', 
    'Place tags',
    'Place description',
    'Physical or online event',
    'Status',
    'Source agenda (uid)',
    'Contributor email', 
    'Contributor phone number',
    'Contributor name', 
    'Contributor function', 
    'Contributor organisation',
    'Category', 
    'Country name', 
    'Registration', 
    'Additionnal links'
    ])

# %%
df
# Out:
#                                                       URL  \
# 5       https://openagenda.com/lete-culturel-2023-en-i...
# 9       https://openagenda.com/centre-tignous-dart-con...
# 11      https://openagenda.com/hormur-plateforme-deven...
# 21      https://openagenda.com/jnarchi-2024-ile-de-fra...
# 37      https://openagenda.com/jep-2024-ile-de-france/...
# ...                                                   ...
# 909865  https://openagenda.com/printemps-des-cimetiere...
# 909866  https://openagenda.com/printemps-des-cimetiere...
# 909867  https://openagenda.com/printemps-des-cimetiere...
# 909885  https://openagenda.com/versailles-palais-des-c...
# 909889  https://openagenda.com/nuit-internationale-de-...
#
#                                                     Title  \
# 5                  Fanfare M'Brass - Fontenay-sous-Soleil
# 9                                 BESTIOLES ÉLECTRONIQUES
# 11      "Kafka Revisitée : Théâtre Intime à Romainvill...
# ...

# %%
df["First date - Start - Date"] = pd.to_datetime(df["First date - Beginning"])
df
# Out:
# C:\Users\marie\AppData\Local\Temp\ipykernel_1792\990548965.py:1: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df["First date - Start - Date"] = pd.to_datetime(df["First date - Beginning"])
#                                                       URL  \
# 5       https://openagenda.com/lete-culturel-2023-en-i...
# 9       https://openagenda.com/centre-tignous-dart-con...
# 11      https://openagenda.com/hormur-plateforme-deven...
# 21      https://openagenda.com/jnarchi-2024-ile-de-fra...
# 37      https://openagenda.com/jep-2024-ile-de-france/...
# ...                                                   ...
# 909865  https://openagenda.com/printemps-des-cimetiere...
# ...

# %%
https://public.opendatasoft.com/api/explore/v2.1/catalog/datasets/evenements-publics-openagenda/records?select=canonicalurl%20as%20URL%2C%20%20title_fr%20as%20Titre%2C%20%20description_fr%20as%20description%2C%20%20longdescription_fr%20as%20description_longue%20%2C%20image%20%2C%20thumbnail%20%2C%20daterange_fr%20as%20date%2C%20firstdate_end%20as%20premier_jour_debut%20%2C%20lastdate_begin%20as%20premier_jour_fin%20%2C%20lastdate_end%20as%20dernier_jour_debut%20%2C%20accessibility_label_fr%20as%20dernier_jour_fin%20%2C%20location_name%20as%20nom_localisation%20%2C%20location_address%20as%20adresse%20%2C%20location_postalcode%20as%20code_postale%20%2C%20location_city%20as%20ville%20%2C%20location_phone%20as%20telephone%20%2C%20location_website%20as%20site_web%20%2C%20location_description_fr%20as%20description_localisation%20%2C%20onlineaccesslink%20as%20lien_acces_en_ligne%20%2C%20age_min%20as%20age_minimum%20%2C%20age_max%20as%20age_maximum%20%2C%20originagenda_title%20as%20source&limit=20&refine=location_region%3A%22Martinique%22&refine=firstdate_begin%3A%222025%22
# Out:
# Index(['URL', 'Title', 'Description', 'Long description', 'Details', 'Image',
#        'Preview', 'Times', 'First date - Beginning', 'First date - End',
#        'Last date - Beginning', 'Last date - End', 'Accessibility',
#        'Place name', 'Address', 'Arrondissement', 'Postal code', 'City',
#        'Department', 'Region', 'Place image', 'Phone number', 'Place website',
#        'Access', 'Online access link', 'Minimum age', 'Maximum age',
#        'Source agenda (title)', 'First date - Start - Date'],
#       dtype='object')

# %%
import locale
from datetime import datetime

locale.setlocale(locale.LC_TIME, "fr_FR")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 3
#       1 import locale
#       2 from datetime import datetime
# ----> 3 import dateparser
#       4 locale.setlocale(locale.LC_TIME, "fr_FR")
#
# ModuleNotFoundError: No module named 'dateparser'

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import swagger
#
# ModuleNotFoundError: No module named 'swagger'

# %%
df['date_test'] = df['Times'].apply(
    lambda x: datetime.strptime(x, "%A %d %B %Y, %Hh%M")
)
df['date_test'].dtype
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df['date_test'] = df['Times'].apply(
#       2     lambda x: datetime.strptime(x, "%A %d %B %Y, %Hh%M")
#       3 )
#       4 df['date_test'].dtype
#
# File d:\oc\projet_7\puls-events-chatbot\.venv\lib\site-packages\pandas\core\series.py:4943, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4808 def apply(
#    4809     self,
#    4810     func: AggFuncType,
#    (...)
#    4815     **kwargs,
#    4816 ) -> DataFrame | Series:
#    4817     """
#    4818     Invoke function on values of Series.
#    4819
#    (...)
#    4934     dtype: float64
#    4935     """
#    4936     return SeriesApply(
#    4937         self,
#    4938         func,
#    4939         convert_dtype=convert_dtype,
#    4940         by_row=by_row,
#    4941         args=args,
# ...

# %%
df["First date - Beginning"] = pd.to_datetime(
    df["First date - Beginning"], 
    format='ISO8601', 
    errors='coerce' 
)
df
# Out:
# C:\Users\marie\AppData\Local\Temp\ipykernel_27816\3066937276.py:1: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df["First date - Beginning"] = pd.to_datetime(
#               ID                                               Slug  \
# 0       15268997               atelier-creation-dentreprise-3243132
# 1       50737223                         la-classe-loeuvre--6944943
# 2       92831157                      visite-atelier-adultesenfants
# 3       53456762                   les-jeudis-de-linsertion-4071122
# 4       67676934  formation-cap-metiers-de-bouche-boucherboulang...
# ...          ...                                                ...
# ...
